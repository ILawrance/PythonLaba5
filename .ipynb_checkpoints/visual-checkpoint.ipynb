# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt



x = np.array([1,2,8])
y = x
plt.plot(x, y, 'g--s')
plt.show()

# %%
z = np.arange(5,51,5)
v = np.arange(10,101,10)
plt.plot(z,v, 'r--s')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 z = np.arange(5,51,5)
#       2 v = np.arange(10,101,10)
# ----> 3 plt.plot(z,v, 'r--s')
#       4 plt.show()
#
# NameError: name 'plt' is not defined
